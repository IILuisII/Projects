# %%
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import psycopg2

# %%
engine = create_engine("postgres://readonly:12345@35.225.151.235:5432/postgres")
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['employees', 'departments', 'dept_emp', 'salaries', 'titles', 'dept_manager']

# %%
conn = engine.connect()

# %%
query = """
            SELECT
                *
            FROM
                salaries
        """

# %%
df = pd.read_sql(query, conn)
df
# Out:
#         salary_id  emp_no  salary               last_updated
# 0               1   10001   60117 2020-05-28 21:33:59.296112
# 1               2   10002   65828 2020-05-28 21:33:59.296112
# 2               3   10003   40006 2020-05-28 21:33:59.296112
# 3               4   10004   40054 2020-05-28 21:33:59.296112
# 4               5   10005   78228 2020-05-28 21:33:59.296112
# ...           ...     ...     ...                        ...
# 300019     300020  499995   40000 2020-05-28 21:35:02.164213
# 300020     300021  499996   58058 2020-05-28 21:35:02.164213
# 300021     300022  499997   49597 2020-05-28 21:35:02.164213
# 300022     300023  499998   40000 2020-05-28 21:35:02.164213
# 300023     300024  499999   63707 2020-05-28 21:35:02.164213
#
# [300024 rows x 4 columns]

# %%
query2 = """
            SELECT
                *
            FROM
                employees
        """

# %%
df2 = pd.read_sql(query2, conn)
df2
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date               last_updated
# 0       1990-04-28 2020-05-28 21:15:41.241322
# 1       1991-09-07 2020-05-28 21:15:41.241322
# ...

# %%
query3 = """
            SELECT
                *
            FROM
                titles
        """

# %%
df3 = pd.read_sql(query3, conn)
df3
# Out:
#   title_id               title               last_updated
# 0    s0001               Staff 2020-05-28 21:39:35.238954
# 1    s0002        Senior Staff 2020-05-28 21:39:35.238954
# 2    e0001  Assistant Engineer 2020-05-28 21:39:35.238954
# 3    e0002            Engineer 2020-05-28 21:39:35.238954
# 4    e0003     Senior Engineer 2020-05-28 21:39:35.238954
# 5    e0004    Technique Leader 2020-05-28 21:39:35.238954
# 6    m0001             Manager 2020-05-28 21:39:35.238954

# %%
# Merge Columns / Combine Data
combined_data = pd.merge(df, df2, on="emp_no", how="inner")
combined_data
# Out:
#         salary_id  emp_no  salary             last_updated_x emp_title_id  \
# 0               1   10001   60117 2020-05-28 21:33:59.296112        e0003
# 1               2   10002   65828 2020-05-28 21:33:59.296112        s0001
# 2               3   10003   40006 2020-05-28 21:33:59.296112        e0003
# 3               4   10004   40054 2020-05-28 21:33:59.296112        e0003
# 4               5   10005   78228 2020-05-28 21:33:59.296112        s0001
# ...           ...     ...     ...                        ...          ...
# 300019     300020  499995   40000 2020-05-28 21:35:02.164213        e0002
# 300020     300021  499996   58058 2020-05-28 21:35:02.164213        e0003
# 300021     300022  499997   49597 2020-05-28 21:35:02.164213        e0003
# 300022     300023  499998   40000 2020-05-28 21:35:02.164213        s0001
# 300023     300024  499999   63707 2020-05-28 21:35:02.164213        e0002
#
#         birth_date first_name last_name sex   hire_date  \
# ...

# %%
combined_data2 = pd.merge(combined_data, df3, left_on="emp_title_id", right_on="title_id", how="inner")
combined_data2.head()
# Out:
#    salary_id  emp_no  salary             last_updated_x emp_title_id  \
# 0          1   10001   60117 2020-05-28 21:33:59.296112        e0003
# 1          3   10003   40006 2020-05-28 21:33:59.296112        e0003
# 2          4   10004   40054 2020-05-28 21:33:59.296112        e0003
# 3          6   10006   40000 2020-05-28 21:33:59.296112        e0003
# 4          9   10009   60929 2020-05-28 21:33:59.296112        e0003
#
#    birth_date first_name last_name sex   hire_date             last_updated_y  \
# 0  1953-09-02     Georgi   Facello   M  1986-06-26 2020-05-28 21:16:48.032974
# 1  1959-12-03      Parto   Bamford   M  1986-08-28 2020-05-28 21:16:04.694519
# 2  1954-05-01  Chirstian   Koblick   M  1986-12-01 2020-05-28 21:16:48.032974
# 3  1953-04-20     Anneke   Preusig   F  1989-06-02 2020-05-28 21:17:11.387383
# 4  1952-04-19     Sumant      Peac   F  1985-02-18 2020-05-28 21:17:01.305493
#
#   title_id            title               last_updated
# ...

# %%
# Groupby Title
grouped_df = combined_data2.groupby("title").mean()
grouped_df
# Out:
#                         salary_id         emp_no        salary
# title
# Assistant Engineer  149982.822451  252992.595373  48564.434447
# Engineer            150134.491998  253654.345919  48535.336511
# Manager             100012.500000  110780.833333  51531.041667
# Senior Engineer     149857.736913  253038.749885  48506.799871
# Senior Staff        150530.990182  254481.798969  58550.172704
# Staff               150114.526615  253408.503604  58465.382850
# Technique Leader    149087.701875  251811.432730  48582.896092

# %%
newdf = grouped_df.drop(columns =['salary_id', 'emp_no']).reset_index()
newdf
# Out:
#                 title        salary
# 0  Assistant Engineer  48564.434447
# 1            Engineer  48535.336511
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.799871
# 4        Senior Staff  58550.172704
# 5               Staff  58465.382850
# 6    Technique Leader  48582.896092

# %%
#bins = [40000, 40001-50000, 50001-60000, 60001-70000, 70001-80000, 80000]
plt.hist(df.salary, bins=10, color="r")
plt.grid(False)
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.title("Salary Frequency")
plt.show()

# %%
plt.bar(newdf["title"], newdf["salary"], color='r', align="center")
plt.xticks(rotation=45)
plt.grid(False)
plt.xlabel("Title")
plt.ylabel("Salary")
plt.title("Average Salary By Title")
plt.show()
